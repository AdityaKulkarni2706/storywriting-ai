# %%
import google.generativeai as genai


#API KEY : AIzaSyDju66-JtD42JqKy6Af5jxJGNGU5kBdNlI

# %%
def generate_text(query, model):

    respone = model.generate_content(query)
    return respone.text

def get_input_query():
    anything_in_mind = (input("Do you have anything in mind for writing? Any specific genres? (y/n) : ")).lower()
    what_user_has_to_offer = "This is what user has to offer : "

    whats_in_mind = ""
    if anything_in_mind == 'y':
        whats_in_mind = input("Shoot anything you want! : ")

        return what_user_has_to_offer + whats_in_mind
    
    if anything_in_mind == 'n':
        print("No problem! Guess someone is going to select a random genre for you!")
        return what_user_has_to_offer + "Select a random genre for me!"
    
    

def query_formatting(default_query, user_query):
    return default_query + user_query

# %%
def main():
    api_key = "AIzaSyDju66-JtD42JqKy6Af5jxJGNGU5kBdNlI"
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel("gemini-2.0-flash-exp")

    default_prompt = "Your goal is to generate ideas of stories for people who are looking for inspiration, and you need to give them something they could use to start with."
    
    query = get_input_query()
    print(query)

    new_query = query_formatting(default_prompt, query)
    print(new_query)

    print(generate_text(new_query, model))

main()
# Out:
# This is what user has to offer : something romantic and intimate, which will make readers go weeee
# Your goal is to generate ideas of stories for people who are looking for inspiration, and you need to give them something they could use to start with.This is what user has to offer : something romantic and intimate, which will make readers go weeee
# Okay, I love this! Romantic and intimate with a "weeee" factor – that's the sweet spot. Let's brainstorm some story ideas that can get those butterflies fluttering and readers swooning. I'll offer a few starting points for each, with a bit of "weeee" potential:
#
# **Idea Category 1: The Unexpected Connection**
#
# *   **Story Idea 1: The Wrong Number, Right Time.**
#     *   **Starting Point:** Imagine a character who accidentally texts the wrong number late at night, and instead of a brusque reply, they get a witty, engaging response that keeps them up all night.
#     *   **"Weeee" Factor:** The slow burn of texting conversations revealing vulnerability, the building anticipation of meeting in person, the realization that maybe fate *did* have a plan.
#     *   **Potential Twists:** One character is a celebrity, they live in different countries, one of them is hiding a secret.
#
# *   **Story Idea 2: The Shared Secret, The Hidden Passageway.**
#     *   **Starting Point:** Two characters discover an old, hidden passageway in a place they both frequent (a library, an old building, a park) and use it as their clandestine meeting spot.
#     *   **"Weeee" Factor:** The thrill of secrecy, the intimacy of their hidden space, the shared adventure that deepens their connection, the anticipation of each meeting in a world that they made their own.
#     *   **Potential Twists:** One character is engaged to someone else, the passageway leads to something dangerous, their secret is about to be discovered.
#
# *   **Story Idea 3: The Opposites Attract, Forced Proximity Edition.**
#     *   **Starting Point:** Two people with completely opposite personalities are forced to work together on a project (a creative endeavor, a road trip, a research assignment) and initially clash, but slowly discover hidden depths in each other.
#     *   **"Weeee" Factor:** The tension between their initial dislike turning into attraction, the vulnerabilities revealed through the process, the realization that what they thought they wanted isn’t what they need.
#     *   **Potential Twists:** One is hiding the reason for their personality, they are competing for a same prize, they are running from their past.
#
# **Idea Category 2: The Second Chance Romance**
#
# *   **Story Idea 4: The Lost Letter, Found Again.**
#     *   **Starting Point:** Years after a relationship ended, a character discovers a letter they wrote but never sent, reigniting old feelings and a longing for what could have been.
